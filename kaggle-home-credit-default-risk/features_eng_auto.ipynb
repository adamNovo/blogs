# %% [markdown]
# # [Home Credit Default Risk](https://www.kaggle.com/c/home-credit-default-risk)
# # Preprocessing - Auto Feature Engineering
# ## Platform: Python 3, colab.research.google.com

# %%
import featuretools as ft
import featuretools.variable_types as vtypes
import pandas as pd
import os
import pandas as pd
import psutil
import numpy as np
import sys

# %%
try:
    from google.colab import drive
    os.environ["runtime"] = "hosted"
    drive.mount('/content/gdrive', force_remount=True)
    project_folder = "/content/gdrive/My Drive/Colab Notebooks/kaggle-home-credit-default-risk"
    if pd.__version__ != "0.24.1":
        # !pip install pandas==0.24.1
        import pandas as pd
except:
    os.environ["runtime"] = "local"
    project_folder = "."
print("Runtime: {}".format(os.environ["runtime"]))
print("Total number of cpus detected: {}.".format(psutil.cpu_count()))
print("Total size of system memory: {:.5f} gb.".format(psutil.virtual_memory().total / 1e9))
# Out:
# Mounted at /content/gdrive
# Runtime: hosted
# Total number of cpus detected: 2.
# Total size of system memory: 13.65532 gb.

# %% [markdown]
# ## Load data

# %%
app = pd.read_csv("{}/data/app_clean.csv".format(project_folder), header=0, index_col=0)
app.shape
# Out:
# (356255, 99)

# %%
# limit files to limit RAM
filename_shards = ["part_1", "part_2"]
current_shard = filename_shards[1]
if current_shard == filename_shards[0]:
    app = app.loc[:180000, :]
elif current_shard == filename_shards[len(filename_shards) - 1]:
    app = app.loc[180000:, :]
app.shape
# Out:
# (176255, 99)

# %%
for i in range(len(app.dtypes)):
    print(app.columns[i], app.dtypes[i])
# Out:
# AMT_ANNUITY float64
# AMT_CREDIT float64
# AMT_GOODS_PRICE float64
# AMT_INCOME_TOTAL float64
# AMT_REQ_CREDIT_BUREAU_DAY float64
# AMT_REQ_CREDIT_BUREAU_HOUR float64
# AMT_REQ_CREDIT_BUREAU_MON float64
# AMT_REQ_CREDIT_BUREAU_QRT float64
# AMT_REQ_CREDIT_BUREAU_WEEK float64
# AMT_REQ_CREDIT_BUREAU_YEAR float64
# APARTMENTS_AVG float64
# APARTMENTS_MEDI float64
# APARTMENTS_MODE float64
# CNT_CHILDREN int64
# CNT_FAM_MEMBERS float64
# CODE_GENDER object
# DAYS_BIRTH int64
# DAYS_EMPLOYED int64
# DAYS_ID_PUBLISH int64
# DAYS_LAST_PHONE_CHANGE float64
# DAYS_REGISTRATION float64
# DEF_30_CNT_SOCIAL_CIRCLE float64
# DEF_60_CNT_SOCIAL_CIRCLE float64
# ELEVATORS_AVG float64
# ELEVATORS_MEDI float64
# ELEVATORS_MODE float64
# EMERGENCYSTATE_MODE object
# ENTRANCES_AVG float64
# ENTRANCES_MEDI float64
# ENTRANCES_MODE float64
# EXT_SOURCE_1 float64
# EXT_SOURCE_2 float64
# EXT_SOURCE_3 float64
# FLAG_CONT_MOBILE int64
# FLAG_DOCUMENT_10 int64
# FLAG_DOCUMENT_11 int64
# FLAG_DOCUMENT_12 int64
# FLAG_DOCUMENT_13 int64
# FLAG_DOCUMENT_14 int64
# FLAG_DOCUMENT_15 int64
# FLAG_DOCUMENT_16 int64
# FLAG_DOCUMENT_17 int64
# FLAG_DOCUMENT_18 int64
# FLAG_DOCUMENT_19 int64
# FLAG_DOCUMENT_2 int64
# FLAG_DOCUMENT_20 int64
# FLAG_DOCUMENT_21 int64
# FLAG_DOCUMENT_3 int64
# FLAG_DOCUMENT_4 int64
# FLAG_DOCUMENT_5 int64
# FLAG_DOCUMENT_6 int64
# FLAG_DOCUMENT_7 int64
# FLAG_DOCUMENT_8 int64
# FLAG_DOCUMENT_9 int64
# FLAG_EMAIL int64
# FLAG_EMP_PHONE int64
# FLAG_MOBIL int64
# FLAG_OWN_CAR object
# FLAG_OWN_REALTY object
# FLAG_PHONE int64
# FLAG_WORK_PHONE int64
# FLOORSMAX_AVG float64
# FLOORSMAX_MEDI float64
# FLOORSMAX_MODE float64
# HOUR_APPR_PROCESS_START int64
# HOUSETYPE_MODE object
# LIVE_CITY_NOT_WORK_CITY int64
# LIVE_REGION_NOT_WORK_REGION int64
# LIVINGAREA_AVG float64
# LIVINGAREA_MEDI float64
# LIVINGAREA_MODE float64
# NAME_CONTRACT_TYPE object
# NAME_EDUCATION_TYPE object
# NAME_FAMILY_STATUS object
# NAME_HOUSING_TYPE object
# NAME_INCOME_TYPE object
# NAME_TYPE_SUITE object
# NONLIVINGAREA_AVG float64
# NONLIVINGAREA_MEDI float64
# NONLIVINGAREA_MODE float64
# OBS_30_CNT_SOCIAL_CIRCLE float64
# OBS_60_CNT_SOCIAL_CIRCLE float64
# OCCUPATION_TYPE object
# ORGANIZATION_TYPE object
# REGION_POPULATION_RELATIVE float64
# REGION_RATING_CLIENT int64
# REGION_RATING_CLIENT_W_CITY int64
# REG_CITY_NOT_LIVE_CITY int64
# REG_CITY_NOT_WORK_CITY int64
# REG_REGION_NOT_LIVE_REGION int64
# REG_REGION_NOT_WORK_REGION int64
# SK_ID_CURR int64
# TARGET float64
# TOTALAREA_MODE float64
# WALLSMATERIAL_MODE object
# WEEKDAY_APPR_PROCESS_START object
# YEARS_BEGINEXPLUATATION_AVG float64
# YEARS_BEGINEXPLUATATION_MEDI float64
# YEARS_BEGINEXPLUATATION_MODE float64

# %%
bureau = pd.read_csv("{}/data/bureau_clean.csv".format(project_folder), header=0, index_col=0)
bureau.shape
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:472: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# (1716428, 16)

# %%
for i in range(len(bureau.dtypes)):
    print(bureau.columns[i], bureau.dtypes[i])
# Out:
# SK_ID_CURR int64
# SK_ID_BUREAU int64
# CREDIT_ACTIVE object
# CREDIT_CURRENCY object
# DAYS_CREDIT int64
# CREDIT_DAY_OVERDUE int64
# DAYS_CREDIT_ENDDATE float64
# DAYS_ENDDATE_FACT float64
# AMT_CREDIT_MAX_OVERDUE float64
# CNT_CREDIT_PROLONG int64
# AMT_CREDIT_SUM float64
# AMT_CREDIT_SUM_DEBT float64
# AMT_CREDIT_SUM_LIMIT float64
# AMT_CREDIT_SUM_OVERDUE float64
# CREDIT_TYPE object
# DAYS_CREDIT_UPDATE int64

# %%
bureau_balance = pd.read_csv("{}/data/bureau_balance_clean.csv".format(project_folder), header=0, index_col=0)
bureau_balance.shape
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:472: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# (27299925, 3)

# %%
for i in range(len(bureau_balance.dtypes)):
    print(bureau_balance.columns[i], bureau_balance.dtypes[i])
# Out:
# SK_ID_BUREAU int64
# MONTHS_BALANCE int64
# STATUS object

# %% [markdown]
# ## Setup ft

# %%
es = ft.EntitySet(id = "loans")

# %% [markdown]
# All indeces must be ints:

# %%
app["SK_ID_CURR"] = np.int64(app["SK_ID_CURR"])
bureau["SK_ID_CURR"] = np.int64(bureau["SK_ID_CURR"])
bureau["SK_ID_BUREAU"] = np.int64(bureau["SK_ID_BUREAU"])
bureau_balance["SK_ID_BUREAU"] = np.int64(bureau_balance["SK_ID_BUREAU"])

# %% [markdown]
# Define boolean and ordinal variables:

# %% [markdown]
# App types

# %%
app_types = {}

# %%
# Ordinal types
for i in [
    "REGION_RATING_CLIENT", 
    "REGION_RATING_CLIENT_W_CITY",
    "HOUR_APPR_PROCESS_START"
]:
    if i in app.columns:
        app_types[i] = vtypes.Ordinal

# %%
# Boolean types
for col in app:
    if (app[col].nunique() == 2) and (app[col].dtype == float):
        app_types[col] = vtypes.Boolean

# %%
app_types.pop("TARGET")
print(app_types)
# Out:
# {'REGION_RATING_CLIENT': <class 'featuretools.variable_types.variable.Ordinal'>, 'REGION_RATING_CLIENT_W_CITY': <class 'featuretools.variable_types.variable.Ordinal'>, 'HOUR_APPR_PROCESS_START': <class 'featuretools.variable_types.variable.Ordinal'>}

# %%
bureau_types = {
    "CREDIT_ACTIVE": vtypes.Categorical,
    "CREDIT_CURRENCY": vtypes.Categorical,
    "CREDIT_TYPE": vtypes.Categorical 
}

# %%
# Boolean types
for col in bureau:
    if (bureau[col].nunique() == 2) and (bureau[col].dtype == float):
        bureau_types[col] = vtypes.Boolean

# %%
print(bureau_types)
# Out:
# {'CREDIT_ACTIVE': <class 'featuretools.variable_types.variable.Categorical'>, 'CREDIT_CURRENCY': <class 'featuretools.variable_types.variable.Categorical'>, 'CREDIT_TYPE': <class 'featuretools.variable_types.variable.Categorical'>}

# %%
bureau_balance_types = {
    "STATUS": vtypes.Categorical
}

# %% [markdown]
# Define entities (tables):

# %%
# Entities with unique index
es = es.entity_from_dataframe(
    entity_id = "app", 
    dataframe = app, 
    index = "SK_ID_CURR", 
    variable_types = app_types
)
es = es.entity_from_dataframe(
    entity_id = "bureau", 
    dataframe = bureau, 
    index = 'SK_ID_BUREAU', 
    variable_types = bureau_types
)
# Entities with no unique index
es = es.entity_from_dataframe(
    entity_id = "bureau_balance", 
    dataframe = bureau_balance, 
    make_index = True, 
    index = "bureaubalance_index", 
    variable_types = bureau_balance_types
)

# %% [markdown]
# Define relationships:

# %%
r_app_bureau = ft.Relationship(es["app"]["SK_ID_CURR"], es["bureau"]["SK_ID_CURR"])
r_bureau_bureau_balance = ft.Relationship(es["bureau"]["SK_ID_BUREAU"], es["bureau_balance"]["SK_ID_BUREAU"])
es = es.add_relationships([r_app_bureau, r_bureau_bureau_balance])
es
# Out:
# Entityset: loans
#   Entities:
#     app [Rows: 176255, Columns: 99]
#     bureau [Rows: 1716428, Columns: 16]
#     bureau_balance [Rows: 27299925, Columns: 4]
#   Relationships:
#     bureau.SK_ID_CURR -> app.SK_ID_CURR
#     bureau_balance.SK_ID_BUREAU -> bureau.SK_ID_BUREAU

# %%
print('Total size of entityset: {:.5f} gb.'.format(sys.getsizeof(es) / 1e9))
# Out:
# Total size of entityset: 4.85400 gb.

# %% [markdown]
# Feature primitives:

# %%
primitives = ft.list_primitives()
primitives.loc[primitives["type"]=="transform", :]
# Out:
#                    name       type  \
# 19            haversine  transform
# 20                   or  transform
# 21                weeks  transform
# 22             latitude  transform
# 23              minutes  transform
# 24                  not  transform
# 25              seconds  transform
# 26                hours  transform
# 27                 isin  transform
# 28                 days  transform
# 29           time_since  transform
# 30                  mod  transform
# 31           characters  transform
# 32              cum_max  transform
# 33             multiply  transform
# 34  time_since_previous  transform
# 35              weekend  transform
# 36               months  transform
# 37                  add  transform
# 38             cum_mean  transform
# 39              is_null  transform
# 40                 year  transform
# 41                month  transform
# 42                  and  transform
# 43            longitude  transform
# 44                 week  transform
# 45               minute  transform
# 46           percentile  transform
# 47                 diff  transform
# 48               second  transform
# 49           days_since  transform
# 50                 hour  transform
# 51                  day  transform
# 52               negate  transform
# 53             numwords  transform
# 54              cum_min  transform
# 55               divide  transform
# 56              weekday  transform
# 57             absolute  transform
# 58            cum_count  transform
# 59             subtract  transform
# 60                years  transform
# 61              cum_sum  transform
#
#                                           description
# 19  Calculate the approximate haversine distance i...
# 20  For two boolean values, determine if one value...
# 21  Transform a Timedelta feature into the number ...
# 22  Returns the first value of the tuple base feat...
# 23  Transform a Timedelta feature into the number ...
# 24  For each value of the base feature, negates th...
# 25  Transform a Timedelta feature into the number ...
# 26  Transform a Timedelta feature into the number ...
# 27  For each value of the base feature, checks whe...
# 28  Transform a Timedelta feature into the number ...
# 29             Calculates time since the cutoff time.
# 30  Creates a transform feature that divides two f...
# 31           Return the characters in a given string.
# 32  Calculates the max of previous values of an in...
# 33  Creates a transform feature that multplies two...
# 34      Compute the time since the previous instance.
# 35  Transform Datetime feature into the boolean of...
# 36  Transform a Timedelta feature into the number ...
# 37  Creates a transform feature that adds two feat...
# 38  Calculates the mean of previous values of an i...
# 39  For each value of base feature, return 'True' ...
# 40        Transform a Datetime feature into the year.
# 41       Transform a Datetime feature into the month.
# 42  For two boolean values, determine if both valu...
# 43  Returns the second value on the tuple base fea...
# 44        Transform a Datetime feature into the week.
# 45      Transform a Datetime feature into the minute.
# 46  For each value of the base feature, determines...
# 47  Compute the difference between the value of a ...
# 48      Transform a Datetime feature into the second.
# 49  For each value of the base feature, compute th...
# 50        Transform a Datetime feature into the hour.
# 51         Transform a Datetime feature into the day.
# 52  Creates a transform feature that negates a fea...
# 53  Returns the words in a given string by countin...
# 54  Calculates the min of previous values of an in...
# 55  Creates a transform feature that divides two f...
# 56  Transform Datetime feature into the boolean of...
# 57                    Absolute value of base feature.
# 58  Calculates the number of previous values of an...
# 59  Creates a transform feature that subtracts two...
# 60  Transform a Timedelta feature into the number ...
# 61  Calculates the sum of previous values of an in...

# %%
agg_primitives =  [
    "max", 
    "median", 
#     "skew", 
    "min", 
    "count", 
#     "std", 
#     "sum", 
    "num_unique"
]
trans_primitives =  [
    "percentile"
]

# %%
target_entity = "app"
max_depth = 2

features = ft.dfs(entityset = es, 
    target_entity = target_entity,
    trans_primitives = trans_primitives,
    agg_primitives = agg_primitives,
    max_depth = max_depth,
    features_only = True)
for i in features:
    print(i)
# Out:
# <Feature: AMT_ANNUITY>
# <Feature: AMT_CREDIT>
# <Feature: AMT_GOODS_PRICE>
# <Feature: AMT_INCOME_TOTAL>
# <Feature: AMT_REQ_CREDIT_BUREAU_DAY>
# <Feature: AMT_REQ_CREDIT_BUREAU_HOUR>
# <Feature: AMT_REQ_CREDIT_BUREAU_MON>
# <Feature: AMT_REQ_CREDIT_BUREAU_QRT>
# <Feature: AMT_REQ_CREDIT_BUREAU_WEEK>
# <Feature: AMT_REQ_CREDIT_BUREAU_YEAR>
# <Feature: APARTMENTS_AVG>
# <Feature: APARTMENTS_MEDI>
# <Feature: APARTMENTS_MODE>
# <Feature: CNT_CHILDREN>
# <Feature: CNT_FAM_MEMBERS>
# <Feature: CODE_GENDER>
# <Feature: DAYS_BIRTH>
# <Feature: DAYS_EMPLOYED>
# <Feature: DAYS_ID_PUBLISH>
# <Feature: DAYS_LAST_PHONE_CHANGE>
# <Feature: DAYS_REGISTRATION>
# <Feature: DEF_30_CNT_SOCIAL_CIRCLE>
# <Feature: DEF_60_CNT_SOCIAL_CIRCLE>
# <Feature: ELEVATORS_AVG>
# <Feature: ELEVATORS_MEDI>
# <Feature: ELEVATORS_MODE>
# <Feature: EMERGENCYSTATE_MODE>
# <Feature: ENTRANCES_AVG>
# <Feature: ENTRANCES_MEDI>
# <Feature: ENTRANCES_MODE>
# <Feature: EXT_SOURCE_1>
# <Feature: EXT_SOURCE_2>
# <Feature: EXT_SOURCE_3>
# <Feature: FLAG_CONT_MOBILE>
# <Feature: FLAG_DOCUMENT_10>
# <Feature: FLAG_DOCUMENT_11>
# <Feature: FLAG_DOCUMENT_12>
# <Feature: FLAG_DOCUMENT_13>
# <Feature: FLAG_DOCUMENT_14>
# <Feature: FLAG_DOCUMENT_15>
# <Feature: FLAG_DOCUMENT_16>
# <Feature: FLAG_DOCUMENT_17>
# <Feature: FLAG_DOCUMENT_18>
# <Feature: FLAG_DOCUMENT_19>
# <Feature: FLAG_DOCUMENT_2>
# <Feature: FLAG_DOCUMENT_20>
# <Feature: FLAG_DOCUMENT_21>
# <Feature: FLAG_DOCUMENT_3>
# <Feature: FLAG_DOCUMENT_4>
# <Feature: FLAG_DOCUMENT_5>
# <Feature: FLAG_DOCUMENT_6>
# <Feature: FLAG_DOCUMENT_7>
# <Feature: FLAG_DOCUMENT_8>
# <Feature: FLAG_DOCUMENT_9>
# <Feature: FLAG_EMAIL>
# <Feature: FLAG_EMP_PHONE>
# <Feature: FLAG_MOBIL>
# <Feature: FLAG_OWN_CAR>
# <Feature: FLAG_OWN_REALTY>
# <Feature: FLAG_PHONE>
# <Feature: FLAG_WORK_PHONE>
# <Feature: FLOORSMAX_AVG>
# <Feature: FLOORSMAX_MEDI>
# <Feature: FLOORSMAX_MODE>
# <Feature: HOUSETYPE_MODE>
# <Feature: LIVE_CITY_NOT_WORK_CITY>
# <Feature: LIVE_REGION_NOT_WORK_REGION>
# <Feature: LIVINGAREA_AVG>
# <Feature: LIVINGAREA_MEDI>
# <Feature: LIVINGAREA_MODE>
# <Feature: NAME_CONTRACT_TYPE>
# <Feature: NAME_EDUCATION_TYPE>
# <Feature: NAME_FAMILY_STATUS>
# <Feature: NAME_HOUSING_TYPE>
# <Feature: NAME_INCOME_TYPE>
# <Feature: NAME_TYPE_SUITE>
# <Feature: NONLIVINGAREA_AVG>
# <Feature: NONLIVINGAREA_MEDI>
# <Feature: NONLIVINGAREA_MODE>
# <Feature: OBS_30_CNT_SOCIAL_CIRCLE>
# <Feature: OBS_60_CNT_SOCIAL_CIRCLE>
# <Feature: OCCUPATION_TYPE>
# <Feature: ORGANIZATION_TYPE>
# <Feature: REGION_POPULATION_RELATIVE>
# <Feature: REG_CITY_NOT_LIVE_CITY>
# <Feature: REG_CITY_NOT_WORK_CITY>
# <Feature: REG_REGION_NOT_LIVE_REGION>
# <Feature: REG_REGION_NOT_WORK_REGION>
# <Feature: TARGET>
# <Feature: TOTALAREA_MODE>
# <Feature: WALLSMATERIAL_MODE>
# <Feature: WEEKDAY_APPR_PROCESS_START>
# <Feature: YEARS_BEGINEXPLUATATION_AVG>
# <Feature: YEARS_BEGINEXPLUATATION_MEDI>
# <Feature: YEARS_BEGINEXPLUATATION_MODE>
# <Feature: REGION_RATING_CLIENT>
# <Feature: REGION_RATING_CLIENT_W_CITY>
# <Feature: HOUR_APPR_PROCESS_START>
# <Feature: MAX(bureau.DAYS_CREDIT)>
# <Feature: MAX(bureau.CREDIT_DAY_OVERDUE)>
# <Feature: MAX(bureau.DAYS_CREDIT_ENDDATE)>
# <Feature: MAX(bureau.DAYS_ENDDATE_FACT)>
# <Feature: MAX(bureau.AMT_CREDIT_MAX_OVERDUE)>
# <Feature: MAX(bureau.CNT_CREDIT_PROLONG)>
# <Feature: MAX(bureau.AMT_CREDIT_SUM)>
# <Feature: MAX(bureau.AMT_CREDIT_SUM_DEBT)>
# <Feature: MAX(bureau.AMT_CREDIT_SUM_LIMIT)>
# <Feature: MAX(bureau.AMT_CREDIT_SUM_OVERDUE)>
# <Feature: MAX(bureau.DAYS_CREDIT_UPDATE)>
# <Feature: MEDIAN(bureau.DAYS_CREDIT)>
# <Feature: MEDIAN(bureau.CREDIT_DAY_OVERDUE)>
# <Feature: MEDIAN(bureau.DAYS_CREDIT_ENDDATE)>
# <Feature: MEDIAN(bureau.DAYS_ENDDATE_FACT)>
# <Feature: MEDIAN(bureau.AMT_CREDIT_MAX_OVERDUE)>
# <Feature: MEDIAN(bureau.CNT_CREDIT_PROLONG)>
# <Feature: MEDIAN(bureau.AMT_CREDIT_SUM)>
# <Feature: MEDIAN(bureau.AMT_CREDIT_SUM_DEBT)>
# <Feature: MEDIAN(bureau.AMT_CREDIT_SUM_LIMIT)>
# <Feature: MEDIAN(bureau.AMT_CREDIT_SUM_OVERDUE)>
# <Feature: MEDIAN(bureau.DAYS_CREDIT_UPDATE)>
# <Feature: MIN(bureau.DAYS_CREDIT)>
# <Feature: MIN(bureau.CREDIT_DAY_OVERDUE)>
# <Feature: MIN(bureau.DAYS_CREDIT_ENDDATE)>
# <Feature: MIN(bureau.DAYS_ENDDATE_FACT)>
# <Feature: MIN(bureau.AMT_CREDIT_MAX_OVERDUE)>
# <Feature: MIN(bureau.CNT_CREDIT_PROLONG)>
# <Feature: MIN(bureau.AMT_CREDIT_SUM)>
# <Feature: MIN(bureau.AMT_CREDIT_SUM_DEBT)>
# <Feature: MIN(bureau.AMT_CREDIT_SUM_LIMIT)>
# <Feature: MIN(bureau.AMT_CREDIT_SUM_OVERDUE)>
# <Feature: MIN(bureau.DAYS_CREDIT_UPDATE)>
# <Feature: COUNT(bureau)>
# <Feature: NUM_UNIQUE(bureau.CREDIT_ACTIVE)>
# <Feature: NUM_UNIQUE(bureau.CREDIT_CURRENCY)>
# <Feature: NUM_UNIQUE(bureau.CREDIT_TYPE)>
# <Feature: MAX(bureau_balance.MONTHS_BALANCE)>
# <Feature: MEDIAN(bureau_balance.MONTHS_BALANCE)>
# <Feature: MIN(bureau_balance.MONTHS_BALANCE)>
# <Feature: COUNT(bureau_balance)>
# <Feature: NUM_UNIQUE(bureau_balance.STATUS)>
# <Feature: PERCENTILE(AMT_ANNUITY)>
# <Feature: PERCENTILE(AMT_CREDIT)>
# <Feature: PERCENTILE(AMT_GOODS_PRICE)>
# <Feature: PERCENTILE(AMT_INCOME_TOTAL)>
# <Feature: PERCENTILE(AMT_REQ_CREDIT_BUREAU_DAY)>
# <Feature: PERCENTILE(AMT_REQ_CREDIT_BUREAU_HOUR)>
# <Feature: PERCENTILE(AMT_REQ_CREDIT_BUREAU_MON)>
# <Feature: PERCENTILE(AMT_REQ_CREDIT_BUREAU_QRT)>
# <Feature: PERCENTILE(AMT_REQ_CREDIT_BUREAU_WEEK)>
# <Feature: PERCENTILE(AMT_REQ_CREDIT_BUREAU_YEAR)>
# <Feature: PERCENTILE(APARTMENTS_AVG)>
# <Feature: PERCENTILE(APARTMENTS_MEDI)>
# <Feature: PERCENTILE(APARTMENTS_MODE)>
# <Feature: PERCENTILE(CNT_CHILDREN)>
# <Feature: PERCENTILE(CNT_FAM_MEMBERS)>
# <Feature: PERCENTILE(DAYS_BIRTH)>
# <Feature: PERCENTILE(DAYS_EMPLOYED)>
# <Feature: PERCENTILE(DAYS_ID_PUBLISH)>
# <Feature: PERCENTILE(DAYS_LAST_PHONE_CHANGE)>
# <Feature: PERCENTILE(DAYS_REGISTRATION)>
# <Feature: PERCENTILE(DEF_30_CNT_SOCIAL_CIRCLE)>
# <Feature: PERCENTILE(DEF_60_CNT_SOCIAL_CIRCLE)>
# <Feature: PERCENTILE(ELEVATORS_AVG)>
# <Feature: PERCENTILE(ELEVATORS_MEDI)>
# <Feature: PERCENTILE(ELEVATORS_MODE)>
# <Feature: PERCENTILE(ENTRANCES_AVG)>
# <Feature: PERCENTILE(ENTRANCES_MEDI)>
# <Feature: PERCENTILE(ENTRANCES_MODE)>
# <Feature: PERCENTILE(EXT_SOURCE_1)>
# <Feature: PERCENTILE(EXT_SOURCE_2)>
# <Feature: PERCENTILE(EXT_SOURCE_3)>
# <Feature: PERCENTILE(FLAG_CONT_MOBILE)>
# <Feature: PERCENTILE(FLAG_DOCUMENT_10)>
# <Feature: PERCENTILE(FLAG_DOCUMENT_11)>
# <Feature: PERCENTILE(FLAG_DOCUMENT_12)>
# <Feature: PERCENTILE(FLAG_DOCUMENT_13)>
# <Feature: PERCENTILE(FLAG_DOCUMENT_14)>
# <Feature: PERCENTILE(FLAG_DOCUMENT_15)>
# <Feature: PERCENTILE(FLAG_DOCUMENT_16)>
# <Feature: PERCENTILE(FLAG_DOCUMENT_17)>
# <Feature: PERCENTILE(FLAG_DOCUMENT_18)>
# <Feature: PERCENTILE(FLAG_DOCUMENT_19)>
# <Feature: PERCENTILE(FLAG_DOCUMENT_2)>
# <Feature: PERCENTILE(FLAG_DOCUMENT_20)>
# <Feature: PERCENTILE(FLAG_DOCUMENT_21)>
# <Feature: PERCENTILE(FLAG_DOCUMENT_3)>
# <Feature: PERCENTILE(FLAG_DOCUMENT_4)>
# <Feature: PERCENTILE(FLAG_DOCUMENT_5)>
# <Feature: PERCENTILE(FLAG_DOCUMENT_6)>
# <Feature: PERCENTILE(FLAG_DOCUMENT_7)>
# <Feature: PERCENTILE(FLAG_DOCUMENT_8)>
# <Feature: PERCENTILE(FLAG_DOCUMENT_9)>
# <Feature: PERCENTILE(FLAG_EMAIL)>
# <Feature: PERCENTILE(FLAG_EMP_PHONE)>
# <Feature: PERCENTILE(FLAG_MOBIL)>
# <Feature: PERCENTILE(FLAG_PHONE)>
# <Feature: PERCENTILE(FLAG_WORK_PHONE)>
# <Feature: PERCENTILE(FLOORSMAX_AVG)>
# <Feature: PERCENTILE(FLOORSMAX_MEDI)>
# <Feature: PERCENTILE(FLOORSMAX_MODE)>
# <Feature: PERCENTILE(LIVE_CITY_NOT_WORK_CITY)>
# <Feature: PERCENTILE(LIVE_REGION_NOT_WORK_REGION)>
# <Feature: PERCENTILE(LIVINGAREA_AVG)>
# <Feature: PERCENTILE(LIVINGAREA_MEDI)>
# <Feature: PERCENTILE(LIVINGAREA_MODE)>
# <Feature: PERCENTILE(NONLIVINGAREA_AVG)>
# <Feature: PERCENTILE(NONLIVINGAREA_MEDI)>
# <Feature: PERCENTILE(NONLIVINGAREA_MODE)>
# <Feature: PERCENTILE(OBS_30_CNT_SOCIAL_CIRCLE)>
# <Feature: PERCENTILE(OBS_60_CNT_SOCIAL_CIRCLE)>
# <Feature: PERCENTILE(REGION_POPULATION_RELATIVE)>
# <Feature: PERCENTILE(REG_CITY_NOT_LIVE_CITY)>
# <Feature: PERCENTILE(REG_CITY_NOT_WORK_CITY)>
# <Feature: PERCENTILE(REG_REGION_NOT_LIVE_REGION)>
# <Feature: PERCENTILE(REG_REGION_NOT_WORK_REGION)>
# <Feature: PERCENTILE(TARGET)>
# <Feature: PERCENTILE(TOTALAREA_MODE)>
# <Feature: PERCENTILE(YEARS_BEGINEXPLUATATION_AVG)>
# <Feature: PERCENTILE(YEARS_BEGINEXPLUATATION_MEDI)>
# <Feature: PERCENTILE(YEARS_BEGINEXPLUATATION_MODE)>
# <Feature: MAX(bureau.MEDIAN(bureau_balance.MONTHS_BALANCE))>
# <Feature: MAX(bureau.MIN(bureau_balance.MONTHS_BALANCE))>
# <Feature: MAX(bureau.COUNT(bureau_balance))>
# <Feature: MAX(bureau.NUM_UNIQUE(bureau_balance.STATUS))>
# <Feature: MAX(bureau.PERCENTILE(DAYS_CREDIT))>
# <Feature: MAX(bureau.PERCENTILE(CREDIT_DAY_OVERDUE))>
# <Feature: MAX(bureau.PERCENTILE(DAYS_CREDIT_ENDDATE))>
# <Feature: MAX(bureau.PERCENTILE(DAYS_ENDDATE_FACT))>
# <Feature: MAX(bureau.PERCENTILE(AMT_CREDIT_MAX_OVERDUE))>
# <Feature: MAX(bureau.PERCENTILE(CNT_CREDIT_PROLONG))>
# <Feature: MAX(bureau.PERCENTILE(AMT_CREDIT_SUM))>
# <Feature: MAX(bureau.PERCENTILE(AMT_CREDIT_SUM_DEBT))>
# <Feature: MAX(bureau.PERCENTILE(AMT_CREDIT_SUM_LIMIT))>
# <Feature: MAX(bureau.PERCENTILE(AMT_CREDIT_SUM_OVERDUE))>
# <Feature: MAX(bureau.PERCENTILE(DAYS_CREDIT_UPDATE))>
# <Feature: MEDIAN(bureau.MAX(bureau_balance.MONTHS_BALANCE))>
# <Feature: MEDIAN(bureau.MEDIAN(bureau_balance.MONTHS_BALANCE))>
# <Feature: MEDIAN(bureau.MIN(bureau_balance.MONTHS_BALANCE))>
# <Feature: MEDIAN(bureau.COUNT(bureau_balance))>
# <Feature: MEDIAN(bureau.NUM_UNIQUE(bureau_balance.STATUS))>
# <Feature: MEDIAN(bureau.PERCENTILE(DAYS_CREDIT))>
# <Feature: MEDIAN(bureau.PERCENTILE(CREDIT_DAY_OVERDUE))>
# <Feature: MEDIAN(bureau.PERCENTILE(DAYS_CREDIT_ENDDATE))>
# <Feature: MEDIAN(bureau.PERCENTILE(DAYS_ENDDATE_FACT))>
# <Feature: MEDIAN(bureau.PERCENTILE(AMT_CREDIT_MAX_OVERDUE))>
# <Feature: MEDIAN(bureau.PERCENTILE(CNT_CREDIT_PROLONG))>
# <Feature: MEDIAN(bureau.PERCENTILE(AMT_CREDIT_SUM))>
# <Feature: MEDIAN(bureau.PERCENTILE(AMT_CREDIT_SUM_DEBT))>
# <Feature: MEDIAN(bureau.PERCENTILE(AMT_CREDIT_SUM_LIMIT))>
# <Feature: MEDIAN(bureau.PERCENTILE(AMT_CREDIT_SUM_OVERDUE))>
# <Feature: MEDIAN(bureau.PERCENTILE(DAYS_CREDIT_UPDATE))>
# <Feature: MIN(bureau.MAX(bureau_balance.MONTHS_BALANCE))>
# <Feature: MIN(bureau.MEDIAN(bureau_balance.MONTHS_BALANCE))>
# <Feature: MIN(bureau.COUNT(bureau_balance))>
# <Feature: MIN(bureau.NUM_UNIQUE(bureau_balance.STATUS))>
# <Feature: MIN(bureau.PERCENTILE(DAYS_CREDIT))>
# <Feature: MIN(bureau.PERCENTILE(CREDIT_DAY_OVERDUE))>
# <Feature: MIN(bureau.PERCENTILE(DAYS_CREDIT_ENDDATE))>
# <Feature: MIN(bureau.PERCENTILE(DAYS_ENDDATE_FACT))>
# <Feature: MIN(bureau.PERCENTILE(AMT_CREDIT_MAX_OVERDUE))>
# <Feature: MIN(bureau.PERCENTILE(CNT_CREDIT_PROLONG))>
# <Feature: MIN(bureau.PERCENTILE(AMT_CREDIT_SUM))>
# <Feature: MIN(bureau.PERCENTILE(AMT_CREDIT_SUM_DEBT))>
# <Feature: MIN(bureau.PERCENTILE(AMT_CREDIT_SUM_LIMIT))>
# <Feature: MIN(bureau.PERCENTILE(AMT_CREDIT_SUM_OVERDUE))>
# <Feature: MIN(bureau.PERCENTILE(DAYS_CREDIT_UPDATE))>
# <Feature: PERCENTILE(MAX(bureau.DAYS_CREDIT))>
# <Feature: PERCENTILE(MAX(bureau.CREDIT_DAY_OVERDUE))>
# <Feature: PERCENTILE(MAX(bureau.DAYS_CREDIT_ENDDATE))>
# <Feature: PERCENTILE(MAX(bureau.DAYS_ENDDATE_FACT))>
# <Feature: PERCENTILE(MAX(bureau.AMT_CREDIT_MAX_OVERDUE))>
# <Feature: PERCENTILE(MAX(bureau.CNT_CREDIT_PROLONG))>
# <Feature: PERCENTILE(MAX(bureau.AMT_CREDIT_SUM))>
# <Feature: PERCENTILE(MAX(bureau.AMT_CREDIT_SUM_DEBT))>
# <Feature: PERCENTILE(MAX(bureau.AMT_CREDIT_SUM_LIMIT))>
# <Feature: PERCENTILE(MAX(bureau.AMT_CREDIT_SUM_OVERDUE))>
# <Feature: PERCENTILE(MAX(bureau.DAYS_CREDIT_UPDATE))>
# <Feature: PERCENTILE(MEDIAN(bureau.DAYS_CREDIT))>
# <Feature: PERCENTILE(MEDIAN(bureau.CREDIT_DAY_OVERDUE))>
# <Feature: PERCENTILE(MEDIAN(bureau.DAYS_CREDIT_ENDDATE))>
# <Feature: PERCENTILE(MEDIAN(bureau.DAYS_ENDDATE_FACT))>
# <Feature: PERCENTILE(MEDIAN(bureau.AMT_CREDIT_MAX_OVERDUE))>
# <Feature: PERCENTILE(MEDIAN(bureau.CNT_CREDIT_PROLONG))>
# <Feature: PERCENTILE(MEDIAN(bureau.AMT_CREDIT_SUM))>
# <Feature: PERCENTILE(MEDIAN(bureau.AMT_CREDIT_SUM_DEBT))>
# <Feature: PERCENTILE(MEDIAN(bureau.AMT_CREDIT_SUM_LIMIT))>
# <Feature: PERCENTILE(MEDIAN(bureau.AMT_CREDIT_SUM_OVERDUE))>
# <Feature: PERCENTILE(MEDIAN(bureau.DAYS_CREDIT_UPDATE))>
# <Feature: PERCENTILE(MIN(bureau.DAYS_CREDIT))>
# <Feature: PERCENTILE(MIN(bureau.CREDIT_DAY_OVERDUE))>
# <Feature: PERCENTILE(MIN(bureau.DAYS_CREDIT_ENDDATE))>
# <Feature: PERCENTILE(MIN(bureau.DAYS_ENDDATE_FACT))>
# <Feature: PERCENTILE(MIN(bureau.AMT_CREDIT_MAX_OVERDUE))>
# <Feature: PERCENTILE(MIN(bureau.CNT_CREDIT_PROLONG))>
# <Feature: PERCENTILE(MIN(bureau.AMT_CREDIT_SUM))>
# <Feature: PERCENTILE(MIN(bureau.AMT_CREDIT_SUM_DEBT))>
# <Feature: PERCENTILE(MIN(bureau.AMT_CREDIT_SUM_LIMIT))>
# <Feature: PERCENTILE(MIN(bureau.AMT_CREDIT_SUM_OVERDUE))>
# <Feature: PERCENTILE(MIN(bureau.DAYS_CREDIT_UPDATE))>
# <Feature: PERCENTILE(COUNT(bureau))>
# <Feature: PERCENTILE(NUM_UNIQUE(bureau.CREDIT_ACTIVE))>
# <Feature: PERCENTILE(NUM_UNIQUE(bureau.CREDIT_CURRENCY))>
# <Feature: PERCENTILE(NUM_UNIQUE(bureau.CREDIT_TYPE))>
# <Feature: PERCENTILE(MAX(bureau_balance.MONTHS_BALANCE))>
# <Feature: PERCENTILE(MEDIAN(bureau_balance.MONTHS_BALANCE))>
# <Feature: PERCENTILE(MIN(bureau_balance.MONTHS_BALANCE))>
# <Feature: PERCENTILE(COUNT(bureau_balance))>
# <Feature: PERCENTILE(NUM_UNIQUE(bureau_balance.STATUS))>

# %%
len(features)
# Out:
# 308

# %%
feature_matrix, features = ft.dfs(entityset = es, 
    target_entity = target_entity,
    trans_primitives = trans_primitives,
    agg_primitives = agg_primitives,
    max_depth = max_depth, n_jobs=1, verbose=1,
    features_only = False,
    chunk_size=0.02)
# Out:
# Built 308 features
# Elapsed: 4:06:49 | Remaining: 1:24:28 | Progress:  75%|███████▍  | Calculated: 38/51 chunks

# %%
feature_matrix.head(5)

# %%
feature_matrix.shape

# %%
for i in feature_matrix.columns:
    print(i)

# %%
feature_matrix_null = feature_matrix.isnull().sum()
fill_na = {}
for i in feature_matrix.columns:
    if feature_matrix_null[i] > 0 and i != "TARGET":
        if feature_matrix[i].dtypes == 'float64':
            fill_na[i] = feature_matrix[i].median()
        else:
            fill_na[i] = feature_matrix[i].mode()[0]
fill_na

# %%
feature_matrix = feature_matrix.fillna(fill_na)
assert sum(feature_matrix.loc[:, "TARGET"].isnull()) == sum(feature_matrix.isnull().sum())

# %%
feature_matrix_train = feature_matrix.loc[feature_matrix["TARGET"].notnull(), :]
feature_matrix_train.to_csv("{}/data/featuretools_matrix_train_{}.csv".format(
    project_folder, current_shard))
feature_matrix_train.shape

# %%
feature_matrix_train_loaded = pd.read_csv("{}/data/featuretools_matrix_train_{}.csv".format(
    project_folder, current_shard), header=0, index_col=0)
assert feature_matrix_train.shape == feature_matrix_train_loaded.shape

# %%
if current_shard == filename_shards[len(filename_shards) - 1]:
    feature_matrix_test = feature_matrix.loc[feature_matrix["TARGET"].isnull(), :]
    feature_matrix_test = feature_matrix_test.drop("TARGET", axis = 1)
    feature_matrix_test.to_csv("{}/data/featuretools_matrix_test.csv".format(project_folder))
    feature_matrix_test.shape
